# %%
import scanpy as sc
import pandas as pd
import numpy as np
from scipy import sparse
import anndata as ad

# %% [markdown]
# #### After filtering
# v228_1 nur obs - in var und counts weiterhin v227_2

# %%
df_anno_new = pd.read_csv('h228_1_qc_integrated_rpca_cellanno_FILTEREDqc_FILTEREDpureCells.txt',sep='\t',index_col = 0)
MA_obs = pd.read_csv('v227_2_MA_obs.csv',index_col = 0)
PR_obs = pd.read_csv('v227_2_PR_obs.csv',index_col = 0)
MA_obs_keep = pd.merge(MA_obs,df_anno_new[['uniform_name_overview_keep']], left_index=True, right_index=True, how='left')
PR_obs_keep = pd.merge(PR_obs,df_anno_new[['uniform_name_overview_keep']], left_index=True, right_index=True, how='left')
# Out:
# /tmp/ipykernel_279053/3282151679.py:1: DtypeWarning: Columns (8,9,11,12,13,14,15,16,18,19,21,22,23,24,25,26,27,29,30,31,32,33,34,35,37,39,40,41,42,43,44,67,69,78,79,80,96,97,100,101,102,106,116) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_anno_new = pd.read_csv('h228_1_qc_integrated_rpca_cellanno_FILTEREDqc_FILTEREDpureCells.txt',sep='\t',index_col = 0)
# /tmp/ipykernel_279053/3282151679.py:2: DtypeWarning: Columns (8,9,11,12,13,14,15,16,18,19,21,22,23,24,25,26,27,29,30,31,32,33,34,35,37,39,40,41,42,43,44,67,69,78,79,80,96,97,100,101,102,105,106) have mixed types. Specify dtype option on import or set low_memory=False.
#   MA_obs = pd.read_csv('v227_2_MA_obs.csv',index_col = 0)
# /tmp/ipykernel_279053/3282151679.py:3: DtypeWarning: Columns (8,9,11,12,13,14,15,16,18,19,21,22,23,24,25,26,27,29,30,31,32,33,34,35,37,39,40,41,42,43,44,67,69,78,79,80,96,97,100,101,102,107,108) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
MA_obs_keep.to_csv('v228_1_MA_obs.csv')
PR_obs_keep.to_csv('v228_1_PR_obs.csv')

# %%
test_MA = pd.read_csv('v228_1_MA_obs.csv',index_col = 0)
# Out:
# /tmp/ipykernel_1353763/3895195511.py:1: DtypeWarning: Columns (8,9,11,12,13,14,15,16,18,19,21,22,23,24,25,26,27,29,30,31,32,33,34,35,37,39,40,41,42,43,44,67,69,78,79,80,96,97,100,101,102,105,106) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_MA = pd.read_csv('v228_1_MA_obs.csv',index_col = 0)

# %%
test_MA
# Out:
#                                       orig.ident  nCount_RNA  nFeature_RNA  \
# rn
# AGTATCTGTACGATGAATGGTTGGACA_3      SeuratProject        1004           448
# AGTAAAGCCAATTATAACTGCATAGTA_3      SeuratProject        1210           573
# GACGGATTACCATGCACAAACGTGTGA_3      SeuratProject        3077           980
# ACCGGATAGTTGCGTACAACAAACTTT_3      SeuratProject        2004           797
# AAGTAACCCACGACCACCAAGTTTACG_3      SeuratProject        1455           600
# ...                                          ...         ...           ...
# ma_e14_blood_3_TCCTCGACAGGATTCT-1             ma        3090           968
# ma_e14_blood_3_TCGGGCACAGGGTTGA-1             ma        3240          1204
# ma_e14_blood_3_TGGAGGATCCGATAAC-1             ma        3372          1295
# ma_e14_blood_3_TTACCGCTCGTACCTC-1             ma        3622          1553
# ma_e14_blood_3_TTTCCTCGTTCAGGTT-1             ma        3196          1454
#
# ...

# %%
test_PR = pd.read_csv('v228_1_PR_obs.csv',index_col = 0)
# Out:
# /tmp/ipykernel_279053/4168625218.py:1: DtypeWarning: Columns (8,9,11,12,13,14,15,16,18,19,21,22,23,24,25,26,27,29,30,31,32,33,34,35,37,39,40,41,42,43,44,67,69,78,79,80,96,97,100,101,102,107,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   test_PR = pd.read_csv('v228_1_PR_obs.csv',index_col = 0)

# %%
test_MA['uniform_name_overview_keep'].value_counts()
# Out:
# True     108009
# False      6519
# Name: uniform_name_overview_keep, dtype: int64

# %%
test_PR['uniform_name_overview_keep'].value_counts()
# Out:
# True     102711
# False      5737
# Name: uniform_name_overview_keep, dtype: int64
